# %%
#importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#Reading the Dataset
dataset = pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset = pd.get_dummies(dataset, drop_first = True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400     False        True
# 1      18  33.770         1   1725.55230      True       False
# 2      28  33.000         3   4449.46200      True       False
# 3      33  22.705         0  21984.47061      True       False
# 4      32  28.880         0   3866.85520      True       False
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830      True       False
# 1334   18  31.920         0   2205.98080     False       False
# 1335   18  36.850         0   1629.83350     False       False
# 1336   21  25.800         0   2007.94500     False       False
# 1337   61  29.070         0  29141.36030     False        True
#
# [1338 rows x 6 columns]

# %%
independent = dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
dependent = dataset[['charges']]

# %%
#split into training set and test set
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(independent, dependent, test_size = 0.30, random_state = 0)

# %%
#Standardisation
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
#to calculate mean and variance
x_train = sc.fit_transform(x_train) #transform: to assign the transform values to x_train
x_test = sc.transform(x_test)

# %%
#GridSearch
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LinearRegression
param_grid = {'fit_intercept':[True, False], 'copy_X':[True, False], 'n_jobs':[1, 5], 'positive':[True, False]}

grid = GridSearchCV(LinearRegression(), param_grid, refit = True, verbose = 3, n_jobs = -1)
#fitting the model for grid search
grid.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# GridSearchCV(estimator=LinearRegression(), n_jobs=-1,
#              param_grid={'copy_X': [True, False],
#                          'fit_intercept': [True, False], 'n_jobs': [1, 5],
#                          'positive': [True, False]},
#              verbose=3)

# %%
#print best parameter after tuning
#print(grid.best_params_)
result = grid.cv_results_

print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'positive': True}:

# %%
table = pd.DataFrame.from_dict(result)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_copy_X  \
# 0        0.004589      0.003994         0.003124        0.005071         True
# 1        0.006623      0.006708         0.000000        0.000000         True
# 2        0.011731      0.003487         0.001240        0.001533         True
# 3        0.005184      0.006417         0.002203        0.001976         True
# 4        0.002195      0.001279         0.000463        0.000926         True
# 5        0.003521      0.003928         0.002110        0.004221         True
# 6        0.014077      0.002305         0.000858        0.001274         True
# 7        0.000739      0.001017         0.003399        0.002956         True
# 8        0.002809      0.003455         0.003380        0.003598        False
# 9        0.002616      0.001758         0.001838        0.002024        False
# 10       0.008419      0.002276         0.003626        0.002331        False
# 11       0.002581      0.002222         0.000811        0.001623        False
# 12       0.002110      0.002367         0.002113        0.002702        False
# 13       0.001111      0.001774         0.002713        0.002614        False
# 14       0.008223      0.002535         0.001003        0.001229        False
# 15       0.003100      0.001721         0.001938        0.001750        False
#
#    param_fit_intercept param_n_jobs param_positive  \
# 0                 True            1           True
# 1                 True            1          False
# 2                 True            5           True
# 3                 True            5          False
# 4                False            1           True
# 5                False            1          False
# 6                False            5           True
# 7                False            5          False
# 8                 True            1           True
# 9                 True            1          False
# 10                True            5           True
# 11                True            5          False
# 12               False            1           True
# 13               False            1          False
# 14               False            5           True
# 15               False            5          False
#
#                                                params  split0_test_score  \
# 0   {'copy_X': True, 'fit_intercept': True, 'n_job...           0.763511
# 1   {'copy_X': True, 'fit_intercept': True, 'n_job...           0.763511
# 2   {'copy_X': True, 'fit_intercept': True, 'n_job...           0.763511
# 3   {'copy_X': True, 'fit_intercept': True, 'n_job...           0.763511
# 4   {'copy_X': True, 'fit_intercept': False, 'n_jo...          -0.698095
# 5   {'copy_X': True, 'fit_intercept': False, 'n_jo...          -0.698095
# 6   {'copy_X': True, 'fit_intercept': False, 'n_jo...          -0.698095
# 7   {'copy_X': True, 'fit_intercept': False, 'n_jo...          -0.698095
# 8   {'copy_X': False, 'fit_intercept': True, 'n_jo...           0.763511
# 9   {'copy_X': False, 'fit_intercept': True, 'n_jo...           0.763511
# 10  {'copy_X': False, 'fit_intercept': True, 'n_jo...           0.763511
# 11  {'copy_X': False, 'fit_intercept': True, 'n_jo...           0.763511
# 12  {'copy_X': False, 'fit_intercept': False, 'n_j...          -0.698095
# 13  {'copy_X': False, 'fit_intercept': False, 'n_j...          -0.698095
# 14  {'copy_X': False, 'fit_intercept': False, 'n_j...          -0.698095
# 15  {'copy_X': False, 'fit_intercept': False, 'n_j...          -0.698095
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.703146           0.730655           0.695634
# 1            0.702938           0.730655           0.695551
# 2            0.703146           0.730655           0.695634
# 3            0.702938           0.730655           0.695551
# 4           -0.586653          -0.459207          -0.598656
# 5           -0.586805          -0.459207          -0.600488
# 6           -0.586653          -0.459207          -0.598656
# 7           -0.586805          -0.459207          -0.600488
# 8            0.703146           0.730655           0.695634
# 9            0.702938           0.730655           0.695551
# 10           0.703146           0.730655           0.695634
# 11           0.702938           0.730655           0.695551
# 12          -0.586653          -0.459207          -0.598656
# 13          -0.586805          -0.459207          -0.600488
# 14          -0.586653          -0.459207          -0.598656
# 15          -0.586805          -0.459207          -0.600488
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.719080         0.722405        0.023902                1
# 1            0.719087         0.722348        0.023954                5
# 2            0.719080         0.722405        0.023902                1
# 3            0.719087         0.722348        0.023954                5
# 4           -0.416113        -0.551745        0.101781                9
# 5           -0.419146        -0.552748        0.101157               13
# 6           -0.416113        -0.551745        0.101781                9
# 7           -0.419146        -0.552748        0.101157               13
# 8            0.719080         0.722405        0.023902                1
# 9            0.719087         0.722348        0.023954                5
# 10           0.719080         0.722405        0.023902                1
# 11           0.719087         0.722348        0.023954                5
# 12          -0.416113        -0.551745        0.101781                9
# 13          -0.419146        -0.552748        0.101157               13
# 14          -0.416113        -0.551745        0.101781                9
# 15          -0.419146        -0.552748        0.101157               13

# %%
age_input = int(input("Age: "))
bmi_input = float(input("BMI: "))
children_input = int(input("Children: "))
sex_male_input = int(input("Sex Male 0 or 1: "))
smoker_yes_input = int(input("Smoker yes 0 or 1: "))
# Out:
# Age: 19
# BMI: 27.9
# Children: 0
# Sex Male 0 or 1: 0
# Smoker yes 0 or 1: 1

# %%
new_data = [[age_input, bmi_input, children_input, sex_male_input, smoker_yes_input]]

# %%
new_data_standardized = sc.transform(new_data)
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
Future_Prediction = grid.predict(new_data_standardized)
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[[25194.15086277]]
