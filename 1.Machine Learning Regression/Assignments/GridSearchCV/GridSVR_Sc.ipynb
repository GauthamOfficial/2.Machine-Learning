# %%
#importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#Reading the Dataset
dataset = pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset = pd.get_dummies(dataset, drop_first = True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400     False        True
# 1      18  33.770         1   1725.55230      True       False
# 2      28  33.000         3   4449.46200      True       False
# 3      33  22.705         0  21984.47061      True       False
# 4      32  28.880         0   3866.85520      True       False
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830      True       False
# 1334   18  31.920         0   2205.98080     False       False
# 1335   18  36.850         0   1629.83350     False       False
# 1336   21  25.800         0   2007.94500     False       False
# 1337   61  29.070         0  29141.36030     False        True
#
# [1338 rows x 6 columns]

# %%
independent = dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
dependent = dataset[['charges']]

# %%
#Standardisation
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
#to calculate mean and variance
independent = sc.fit_transform(independent)
independent = sc.transform(independent)
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
#GridSearch
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
param_grid = {'kernel':['rbf', 'poly', 'sigmoid', 'linear'], 'C':[1, 10], 'gamma':['auto', 'scale']}

grid = GridSearchCV(SVR(), param_grid, refit = True, verbose = 3, n_jobs = -1) #refit->True:To select the best model, otherwise it will select the final model of the combination

#fitting the model for grid search
grid.fit(independent, dependent)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [1, 10], 'gamma': ['auto', 'scale'],
#                          'kernel': ['rbf', 'poly', 'sigmoid', 'linear']},
#              verbose=3)

# %%
#print best parameter after tuning
#print(grid.best_params_)
result = grid.cv_results_

print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'C': 10, 'gamma': 'auto', 'kernel': 'poly'}:

# %%
table = pd.DataFrame.from_dict(result)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.119344      0.007111         0.055630        0.006212       1
# 1        0.084219      0.002850         0.018935        0.006447       1
# 2        0.128714      0.002048         0.023981        0.002308       1
# 3        0.077641      0.001905         0.013235        0.004743       1
# 4        0.107005      0.003122         0.053610        0.004309       1
# 5        0.086884      0.001372         0.015218        0.000826       1
# 6        0.128902      0.004480         0.027483        0.003731       1
# 7        0.077961      0.001923         0.013706        0.005265       1
# 8        0.106751      0.003831         0.053626        0.006261      10
# 9        0.093799      0.001733         0.015593        0.002269      10
# 10       0.129754      0.002310         0.032214        0.005648      10
# 11       0.085577      0.004100         0.014593        0.001920      10
# 12       0.108397      0.002880         0.053567        0.005766      10
# 13       0.081920      0.003725         0.014476        0.001618      10
# 14       0.126322      0.006788         0.024189        0.006204      10
# 15       0.076435      0.010740         0.013945        0.001800      10
#
#    param_gamma param_kernel                                            params  \
# 0         auto          rbf        {'C': 1, 'gamma': 'auto', 'kernel': 'rbf'}
# 1         auto         poly       {'C': 1, 'gamma': 'auto', 'kernel': 'poly'}
# 2         auto      sigmoid    {'C': 1, 'gamma': 'auto', 'kernel': 'sigmoid'}
# 3         auto       linear     {'C': 1, 'gamma': 'auto', 'kernel': 'linear'}
# 4        scale          rbf       {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'}
# 5        scale         poly      {'C': 1, 'gamma': 'scale', 'kernel': 'poly'}
# 6        scale      sigmoid   {'C': 1, 'gamma': 'scale', 'kernel': 'sigmoid'}
# 7        scale       linear    {'C': 1, 'gamma': 'scale', 'kernel': 'linear'}
# 8         auto          rbf       {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}
# 9         auto         poly      {'C': 10, 'gamma': 'auto', 'kernel': 'poly'}
# 10        auto      sigmoid   {'C': 10, 'gamma': 'auto', 'kernel': 'sigmoid'}
# 11        auto       linear    {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}
# 12       scale          rbf      {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# 13       scale         poly     {'C': 10, 'gamma': 'scale', 'kernel': 'poly'}
# 14       scale      sigmoid  {'C': 10, 'gamma': 'scale', 'kernel': 'sigmoid'}
# 15       scale       linear   {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}
#
#     split0_test_score  split1_test_score  split2_test_score  \
# 0           -0.102629          -0.102673          -0.071047
# 1            0.618205           0.584543           0.611632
# 2           -0.115325          -0.113564          -0.081603
# 3            0.276395           0.257635           0.278820
# 4           -0.098791          -0.098582          -0.066868
# 5            0.033079           0.022393           0.051875
# 6           -0.110820          -0.109141          -0.077248
# 7            0.276395           0.257635           0.278820
# 8            0.002592           0.000368           0.028466
# 9            0.690770           0.662091           0.696104
# 10          -0.115296          -0.113529          -0.081560
# 11           0.571353           0.513732           0.556396
# 12           0.037050           0.035702           0.062391
# 13           0.438232           0.377690           0.411459
# 14          -0.072254          -0.070178          -0.039718
# 15           0.571353           0.513732           0.556396
#
#     split3_test_score  split4_test_score  mean_test_score  std_test_score  \
# 0           -0.094928          -0.094331        -0.093122        0.011607
# 1            0.593010           0.662310         0.613940        0.027076
# 2           -0.106061          -0.107193        -0.104749        0.012108
# 3            0.275516           0.281385         0.273950        0.008410
# 4           -0.090853          -0.090622        -0.089143        0.011691
# 5            0.038526           0.038604         0.036895        0.009538
# 6           -0.101680          -0.102924        -0.100362        0.012075
# 7            0.275516           0.281385         0.273950        0.008410
# 8            0.011664           0.010021         0.010622        0.009894
# 9            0.661033           0.730844         0.688168        0.025719
# 10          -0.106009          -0.107175        -0.104714        0.012112
# 11           0.561609           0.578603         0.556339        0.022646
# 12           0.045345           0.046377         0.045373        0.009523
# 13           0.424124           0.434110         0.417123        0.021773
# 14          -0.064935          -0.064801        -0.062377        0.011699
# 15           0.561609           0.578603         0.556339        0.022646
#
#     rank_test_score
# 0                13
# 1                 2
# 2                16
# 3                 6
# 4                12
# 5                 9
# 6                14
# 7                 6
# 8                10
# 9                 1
# 10               15
# 11                3
# 12                8
# 13                5
# 14               11
# 15                3

# %%
age_input = int(input("Age: "))
bmi_input = float(input("BMI: "))
children_input = int(input("Children: "))
sex_male_input = int(input("Sex Male 0 or 1: "))
smoker_yes_input = int(input("Smoker yes 0 or 1: "))
# Out:
# Age: 19
# BMI: 27.9
# Children: 0
# Sex Male 0 or 1: 0
# Smoker yes 0 or 1: 1

# %%
new_data = [[age_input, bmi_input, children_input, sex_male_input, smoker_yes_input]]

# %%
new_data_standardized = sc.transform(new_data)
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
Future_Prediction = grid.predict(new_data_standardized)
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[44153.53757597]
