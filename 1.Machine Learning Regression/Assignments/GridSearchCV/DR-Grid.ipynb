# %%
#importing the libraries
import numpy as np #for array and matrices
import matplotlib.pyplot as plt
import pandas as pd

# %%
#Reading the Dataset
dataset = pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset = pd.get_dummies(dataset, drop_first = True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400     False        True
# 1      18  33.770         1   1725.55230      True       False
# 2      28  33.000         3   4449.46200      True       False
# 3      33  22.705         0  21984.47061      True       False
# 4      32  28.880         0   3866.85520      True       False
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830      True       False
# 1334   18  31.920         0   2205.98080     False       False
# 1335   18  36.850         0   1629.83350     False       False
# 1336   21  25.800         0   2007.94500     False       False
# 1337   61  29.070         0  29141.36030     False        True
#
# [1338 rows x 6 columns]

# %%
independent = dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
dependent = dataset[['charges']]

# %%
#split into training set and test set
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(independent, dependent, test_size = 0.30, random_state = 0)

# %%
#Standardisation
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
#to calculate mean and variance
x_train = sc.fit_transform(x_train) #transform: to assign the transform values to x_train
x_test = sc.transform(x_test)

# %%
#GridSearch
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param_grid = {'criterion':['squared_error', 'friedman_mse', 'poisson' ], 'max_features':['auto', 'sqrt', 'log2'], 'splitter':['best', 'random']}

grid = GridSearchCV(DecisionTreeRegressor(), param_grid, refit = True, verbose = 3, n_jobs = -1) 
#fitting the model for grid search
grid.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 30 fits failed out of a total of 90.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 6 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\User\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\Users\User\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\User\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 24 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\User\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\Users\User\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\User\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:976: UserWarning: One or more of the test scores are non-finite: [       nan        nan 0.60283132 0.59685916 0.62485801 0.62492992
#         nan        nan 0.6467258  0.58356863 0.56137356 0.59177592
#         nan        nan 0.65210217 0.62381248 0.65772165 0.62421354]
#   warnings.warn(
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'poisson'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
#print best parameter after tuning
#print(grid.best_params_)
result = grid.cv_results_

print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'criterion': 'poisson', 'max_features': 'log2', 'splitter': 'best'}:

# %%
table = pd.DataFrame.from_dict(result)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.000000      0.000000         0.000000        0.000000
# 1        0.000673      0.000829         0.000000        0.000000
# 2        0.010143      0.004923         0.000937        0.001874
# 3        0.004745      0.004459         0.002342        0.004685
# 4        0.010859      0.005619         0.001003        0.002005
# 5        0.000890      0.001375         0.004480        0.004539
# 6        0.001168      0.002337         0.000000        0.000000
# 7        0.001182      0.001405         0.000000        0.000000
# 8        0.006323      0.000663         0.001514        0.001874
# 9        0.005058      0.002875         0.003963        0.002244
# 10       0.006652      0.002464         0.002144        0.002121
# 11       0.005173      0.002989         0.001988        0.001629
# 12       0.001058      0.001361         0.000000        0.000000
# 13       0.002043      0.002505         0.000000        0.000000
# 14       0.007827      0.004834         0.003971        0.005758
# 15       0.006467      0.006176         0.000394        0.000788
# 16       0.006883      0.004568         0.002970        0.002819
# 17       0.005204      0.002968         0.001845        0.002451
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               auto           best
# 1    squared_error               auto         random
# 2    squared_error               sqrt           best
# 3    squared_error               sqrt         random
# 4    squared_error               log2           best
# 5    squared_error               log2         random
# 6     friedman_mse               auto           best
# 7     friedman_mse               auto         random
# 8     friedman_mse               sqrt           best
# 9     friedman_mse               sqrt         random
# 10    friedman_mse               log2           best
# 11    friedman_mse               log2         random
# 12         poisson               auto           best
# 13         poisson               auto         random
# 14         poisson               sqrt           best
# 15         poisson               sqrt         random
# 16         poisson               log2           best
# 17         poisson               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...                NaN
# 1   {'criterion': 'squared_error', 'max_features':...                NaN
# 2   {'criterion': 'squared_error', 'max_features':...           0.629809
# 3   {'criterion': 'squared_error', 'max_features':...           0.633907
# 4   {'criterion': 'squared_error', 'max_features':...           0.727329
# 5   {'criterion': 'squared_error', 'max_features':...           0.601663
# 6   {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 7   {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 8   {'criterion': 'friedman_mse', 'max_features': ...           0.687619
# 9   {'criterion': 'friedman_mse', 'max_features': ...           0.656904
# 10  {'criterion': 'friedman_mse', 'max_features': ...           0.693596
# 11  {'criterion': 'friedman_mse', 'max_features': ...           0.804147
# 12  {'criterion': 'poisson', 'max_features': 'auto...                NaN
# 13  {'criterion': 'poisson', 'max_features': 'auto...                NaN
# 14  {'criterion': 'poisson', 'max_features': 'sqrt...           0.755506
# 15  {'criterion': 'poisson', 'max_features': 'sqrt...           0.695379
# 16  {'criterion': 'poisson', 'max_features': 'log2...           0.711751
# 17  {'criterion': 'poisson', 'max_features': 'log2...           0.706862
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0                 NaN                NaN                NaN
# 1                 NaN                NaN                NaN
# 2            0.643403           0.677120           0.550342
# 3            0.616141           0.606731           0.546516
# 4            0.574621           0.511974           0.639831
# 5            0.659991           0.693138           0.505075
# 6                 NaN                NaN                NaN
# 7                 NaN                NaN                NaN
# 8            0.583630           0.672452           0.670807
# 9            0.501064           0.538192           0.581883
# 10           0.575263           0.353852           0.585519
# 11           0.450191           0.500440           0.609343
# 12                NaN                NaN                NaN
# 13                NaN                NaN                NaN
# 14           0.517533           0.633310           0.704855
# 15           0.623881           0.642267           0.600678
# 16           0.770750           0.684145           0.583853
# 17           0.547002           0.572101           0.662252
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 NaN              NaN             NaN               13
# 1                 NaN              NaN             NaN               13
# 2            0.513482         0.602831        0.061043                8
# 3            0.581001         0.596859        0.030423                9
# 4            0.670535         0.624858        0.074937                5
# 5            0.664783         0.624930        0.066897                4
# 6                 NaN              NaN             NaN               13
# 7                 NaN              NaN             NaN               13
# 8            0.619121         0.646726        0.039133                3
# 9            0.639801         0.583569        0.059007               11
# 10           0.598638         0.561374        0.111993               12
# 11           0.594759         0.591776        0.121497               10
# 12                NaN              NaN             NaN               13
# 13                NaN              NaN             NaN               13
# 14           0.649307         0.652102        0.079931                2
# 15           0.556857         0.623812        0.045784                7
# 16           0.538110         0.657722        0.085037                1
# 17           0.632851         0.624214        0.058360                6

# %%
age_input = int(input("Age: "))
bmi_input = float(input("BMI: "))
children_input = int(input("Children: "))
sex_male_input = int(input("Sex Male 0 or 1: "))
smoker_yes_input = int(input("Smoker yes 0 or 1: "))
# Out:
# Age: 19
# BMI: 27.9
# Children: 0
# Sex Male 0 or 1: 0
# Smoker yes 0 or 1: 1

# %%
new_data = [[age_input, bmi_input, children_input, sex_male_input, smoker_yes_input]]

# %%
new_data_standardized = sc.transform(new_data)
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
Future_Prediction = grid.predict(new_data_standardized)
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[16884.924]
